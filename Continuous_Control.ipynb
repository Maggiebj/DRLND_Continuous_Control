# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
#Unity Machine Learning Agents allows researchers and developers to transform games and simulations created 
#using the Unity Editor into environments where intelligent agents can be trained using reinforcement learning, 
#evolutionary strategies, or other machine learning methods through a simple to use Python API.

import numpy as np
import random
import torch
from collections import deque
import matplotlib.pyplot as plt
import os
# %matplotlib inline

from ddpg_agent import Agent

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='Reacher_Linux_NoVis/Reacher_Linux_NoVis/Reacher.x86_64')#"headless" version of the environment. 

#env = UnityEnvironment(file_name='Reacher_Linux/Reacher_Linux/Reacher.x86_64')#enable virtual screen
#https://github.com/Unity-Technologies/ml-agents/blob/main/docs/Training-on-Amazon-Web-Service.md
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]
print (brain)
# Out:
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726671e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
'''
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
'''
# Out:
# "\nenv_info = env.reset(train_mode=False)[brain_name]     # reset the environment    \nstates = env_info.vector_observations                  # get the current state (for each agent)\nscores = np.zeros(num_agents)                          # initialize the score (for each agent)\nwhile True:\n    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)\n    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1\n    env_info = env.step(actions)[brain_name]           # send all actions to tne environment\n    next_states = env_info.vector_observations         # get next state (for each agent)\n    rewards = env_info.rewards                         # get reward (for each agent)\n    dones = env_info.local_done                        # see if episode finished\n    scores += env_info.rewards                         # update the score (for each agent)\n    states = next_states                               # roll over states to next time step\n    if np.any(dones):                                  # exit loop if episode finished\n        break\nprint('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))\n"

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
env_info = env.reset(train_mode=True)[brain_name]

agent = Agent(state_size=state_size,
              action_size=action_size,
              random_seed=10)

# %%
# select an action (for each agent)
actions = np.random.randn(num_agents, action_size) 
actions = np.clip(actions, -1, 1)
print (actions.shape)
# Out:
# (1, 4)

# %%
#explore attributes of BrianInfo
step_info = env.step(actions)[brain_name]

states = step_info.vector_observations
memories = step_info.memories
rewards = step_info.rewards
dones = step_info.local_done
actions = step_info.previous_vector_actions
agents = step_info.agents
print (states,memories,rewards,dones,actions)
print (agents)
# Out:
# [[-1.01524353e-01 -3.99566483e+00 -1.76119626e-01  9.99680221e-01
#   -1.26252249e-02 -2.33226398e-04 -2.19103452e-02  8.70086551e-01
#    1.32839866e-02 -5.01739323e-01 -2.01769853e+00  1.23310365e-01
#   -3.49570823e+00 -6.92691803e-02 -9.98338890e+00 -6.45728111e-02
#    9.99015629e-01  1.79562047e-02 -1.93693442e-03  4.05186079e-02
#   -1.61118007e+00  1.10591665e-01  7.10067630e-01 -3.39309633e-01
#    6.35136187e-01  1.05505049e+00 -6.11648560e+00 -1.00000000e+00
#   -5.15641546e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -5.33014059e-01]] [] [0.0] [False] [[ 0.77077764 -1.         -0.92571908  0.11067145]]
# [922]

# %%
import time

def ddpg(n_episodes=1000, max_t=1000, print_every=20):
    scores_deque = deque(maxlen=print_every)
    scores = []
    eps = EPS_START
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        state = env_info.vector_observations #2D
        #print (state.shape)
        agent.reset()
        agents_scores = np.zeros(num_agents)
        for t in range(max_t):
            action = agent.act(state)
            step_info= env.step(action)[brain_name]
            next_state = step_info.vector_observations#2D
            reward = step_info.rewards#1D
            done = step_info.local_done#1D
            agent.step(state, action, reward, next_state, done)
        
            state = next_state
            agents_scores += reward
            
            
            if any(done):
                #print ("\t score:",agents_scores)
                break 
        ep_avg_agents_score = np.mean(agents_scores)
        scores_deque.append(ep_avg_agents_score)
        scores.append(ep_avg_agents_score)
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, ep_avg_agents_score, end=""))
       
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score of deque: {:.2f}'.format(i_episode, np.mean(scores_deque)))
        
        mean = np.mean(scores_deque)
        if mean > 30.:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score of deque: {:.2f}'.format(i_episode, np.mean(scores_deque)))
            torch.save(agent.actor_local.state_dict(), 'solved_actor_trained_model.pth')
            torch.save(agent.critic_local.state_dict(), 'solved_critic_trained_model.pth')
            break
            
    return scores
start=time.time()
scores = ddpg()
print ("duration:",(time.time()-start)/60)

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 1	Average Score: 1.22
# Episode 2	Average Score: 0.59
# Episode 3	Average Score: 0.35
# Episode 4	Average Score: 1.33
# Episode 5	Average Score: 0.90
# Episode 6	Average Score: 0.54
# Episode 7	Average Score: 0.53
# Episode 8	Average Score: 0.43
# Episode 9	Average Score: 0.15
# Episode 10	Average Score: 1.30
# Episode 11	Average Score: 0.19
# Episode 12	Average Score: 0.28
# Episode 13	Average Score: 0.00
# Episode 14	Average Score: 0.30
# Episode 15	Average Score: 0.27
# Episode 16	Average Score: 0.47
# Episode 17	Average Score: 1.44
# Episode 18	Average Score: 0.87
# Episode 19	Average Score: 0.15
# Episode 20	Average Score: 0.00
# Episode 20	Average Score of deque: 0.57
# Episode 21	Average Score: 0.38
# Episode 22	Average Score: 0.82
# Episode 23	Average Score: 0.99
# Episode 24	Average Score: 0.64
# Episode 25	Average Score: 0.00
# Episode 26	Average Score: 0.11
# Episode 27	Average Score: 0.23
# Episode 28	Average Score: 0.28
# Episode 29	Average Score: 0.00
# Episode 30	Average Score: 0.39
# Episode 31	Average Score: 0.00
# Episode 32	Average Score: 0.29
# Episode 33	Average Score: 0.10
# Episode 34	Average Score: 1.32
# Episode 35	Average Score: 1.00
# Episode 36	Average Score: 0.00
# Episode 37	Average Score: 1.05
# Episode 38	Average Score: 0.99
# Episode 39	Average Score: 0.00
# Episode 40	Average Score: 0.70
# Episode 40	Average Score of deque: 0.46
# Episode 41	Average Score: 1.47
# Episode 42	Average Score: 0.77
# Episode 43	Average Score: 1.23
# Episode 44	Average Score: 0.85
# Episode 45	Average Score: 0.22
# Episode 46	Average Score: 0.86
# Episode 47	Average Score: 0.00
# Episode 48	Average Score: 1.41
# Episode 49	Average Score: 0.00
# Episode 50	Average Score: 1.84
# Episode 51	Average Score: 0.12
# Episode 52	Average Score: 0.55
# Episode 53	Average Score: 0.06
# Episode 54	Average Score: 0.34
# Episode 55	Average Score: 0.06
# Episode 56	Average Score: 1.65
# Episode 57	Average Score: 1.04
# Episode 58	Average Score: 0.45
# Episode 59	Average Score: 1.69
# Episode 60	Average Score: 0.06
# Episode 60	Average Score of deque: 0.73
# Episode 61	Average Score: 0.44
# Episode 62	Average Score: 1.35
# Episode 63	Average Score: 0.11
# Episode 64	Average Score: 0.27
# Episode 65	Average Score: 0.00
# Episode 66	Average Score: 0.91
# Episode 67	Average Score: 0.85
# Episode 68	Average Score: 1.15
# Episode 69	Average Score: 1.18
# Episode 70	Average Score: 1.21
# Episode 71	Average Score: 1.03
# Episode 72	Average Score: 1.57
# Episode 73	Average Score: 0.85
# Episode 74	Average Score: 1.48
# Episode 75	Average Score: 0.38
# Episode 76	Average Score: 1.16
# Episode 77	Average Score: 2.14
# Episode 78	Average Score: 0.14
# Episode 79	Average Score: 1.02
# Episode 80	Average Score: 0.62
# Episode 80	Average Score of deque: 0.89
# Episode 81	Average Score: 1.22
# Episode 82	Average Score: 1.61
# Episode 83	Average Score: 1.69
# Episode 84	Average Score: 1.79
# Episode 85	Average Score: 0.35
# Episode 86	Average Score: 0.71
# Episode 87	Average Score: 0.68
# Episode 88	Average Score: 1.37
# Episode 89	Average Score: 2.38
# Episode 90	Average Score: 0.33
# Episode 91	Average Score: 1.43
# Episode 92	Average Score: 1.67
# Episode 93	Average Score: 2.26
# Episode 94	Average Score: 1.37
# Episode 95	Average Score: 1.05
# Episode 96	Average Score: 0.38
# Episode 97	Average Score: 0.67
# Episode 98	Average Score: 1.59
# Episode 99	Average Score: 0.17
# Episode 100	Average Score: 1.20
# Episode 100	Average Score of deque: 1.20
# Episode 101	Average Score: 0.84
# Episode 102	Average Score: 1.12
# Episode 103	Average Score: 0.89
# Episode 104	Average Score: 1.06
# Episode 105	Average Score: 0.83
# Episode 106	Average Score: 0.14
# Episode 107	Average Score: 2.61
# Episode 108	Average Score: 1.17
# Episode 109	Average Score: 1.71
# Episode 110	Average Score: 2.24
# Episode 111	Average Score: 3.61
# Episode 112	Average Score: 2.77
# Episode 113	Average Score: 2.57
# Episode 114	Average Score: 0.68
# Episode 115	Average Score: 0.61
# Episode 116	Average Score: 1.44
# Episode 117	Average Score: 2.37
# Episode 118	Average Score: 0.44
# Episode 119	Average Score: 0.14
# Episode 120	Average Score: 0.32
# Episode 120	Average Score of deque: 1.38
# Episode 121	Average Score: 3.73
# Episode 122	Average Score: 0.90
# Episode 123	Average Score: 0.39
# Episode 124	Average Score: 0.91
# Episode 125	Average Score: 0.45
# Episode 126	Average Score: 2.91
# Episode 127	Average Score: 0.51
# Episode 128	Average Score: 0.57
# Episode 129	Average Score: 1.71
# Episode 130	Average Score: 2.15
# Episode 131	Average Score: 0.12
# Episode 132	Average Score: 0.38
# Episode 133	Average Score: 2.51
# Episode 134	Average Score: 0.03
# Episode 135	Average Score: 0.57
# Episode 136	Average Score: 3.87
# Episode 137	Average Score: 0.54
# Episode 138	Average Score: 2.58
# Episode 139	Average Score: 0.59
# Episode 140	Average Score: 0.26
# Episode 140	Average Score of deque: 1.28
# Episode 141	Average Score: 1.43
# Episode 142	Average Score: 3.21
# Episode 143	Average Score: 0.29
# Episode 144	Average Score: 0.22
# Episode 145	Average Score: 2.93
# Episode 146	Average Score: 1.79
# Episode 147	Average Score: 1.25
# Episode 148	Average Score: 1.13
# Episode 149	Average Score: 0.76
# Episode 150	Average Score: 2.48
# Episode 151	Average Score: 1.19
# Episode 152	Average Score: 1.20
# Episode 153	Average Score: 2.85
# Episode 154	Average Score: 1.90
# Episode 155	Average Score: 3.20
# Episode 156	Average Score: 0.20
# Episode 157	Average Score: 1.43
# Episode 158	Average Score: 0.42
# Episode 159	Average Score: 1.61
# Episode 160	Average Score: 1.44
# Episode 160	Average Score of deque: 1.55
# Episode 161	Average Score: 1.72
# Episode 162	Average Score: 3.91
# Episode 163	Average Score: 1.28
# Episode 164	Average Score: 3.51
# Episode 165	Average Score: 0.27
# Episode 166	Average Score: 3.51
# Episode 167	Average Score: 2.79
# Episode 168	Average Score: 5.98
# Episode 169	Average Score: 2.47
# Episode 170	Average Score: 4.00
# Episode 171	Average Score: 2.46
# Episode 172	Average Score: 6.50
# Episode 173	Average Score: 2.07
# Episode 174	Average Score: 3.95
# Episode 175	Average Score: 1.20
# Episode 176	Average Score: 3.45
# Episode 177	Average Score: 1.32
# Episode 178	Average Score: 2.89
# Episode 179	Average Score: 4.90
# Episode 180	Average Score: 2.96
# Episode 180	Average Score of deque: 3.06
# Episode 181	Average Score: 3.22
# Episode 182	Average Score: 1.09
# Episode 183	Average Score: 3.31
# Episode 184	Average Score: 1.26
# Episode 185	Average Score: 3.56
# Episode 186	Average Score: 7.09
# Episode 187	Average Score: 1.58
# Episode 188	Average Score: 2.05
# Episode 189	Average Score: 0.86
# Episode 190	Average Score: 2.59
# Episode 191	Average Score: 3.29
# Episode 192	Average Score: 3.09
# Episode 193	Average Score: 4.34
# Episode 194	Average Score: 5.42
# Episode 195	Average Score: 2.29
# Episode 196	Average Score: 1.10
# Episode 197	Average Score: 5.78
# Episode 198	Average Score: 2.68
# Episode 199	Average Score: 4.56
# Episode 200	Average Score: 4.74
# Episode 200	Average Score of deque: 3.19
# Episode 201	Average Score: 4.29
# Episode 202	Average Score: 5.21
# Episode 203	Average Score: 3.27
# Episode 204	Average Score: 1.76
# Episode 205	Average Score: 10.31
# Episode 206	Average Score: 4.10
# Episode 207	Average Score: 5.14
# Episode 208	Average Score: 5.53
# Episode 209	Average Score: 4.16
# Episode 210	Average Score: 7.23
# Episode 211	Average Score: 1.96
# Episode 212	Average Score: 0.80
# Episode 213	Average Score: 4.74
# Episode 214	Average Score: 3.16
# Episode 215	Average Score: 5.82
# Episode 216	Average Score: 4.21
# Episode 217	Average Score: 0.87
# Episode 218	Average Score: 5.80
# Episode 219	Average Score: 2.63
# Episode 220	Average Score: 3.85
# Episode 220	Average Score of deque: 4.24
# Episode 221	Average Score: 9.71
# Episode 222	Average Score: 1.02
# Episode 223	Average Score: 1.80
# Episode 224	Average Score: 8.07
# Episode 225	Average Score: 2.97
# Episode 226	Average Score: 4.41
# Episode 227	Average Score: 12.44
# Episode 228	Average Score: 8.88
# Episode 229	Average Score: 2.72
# Episode 230	Average Score: 4.30
# Episode 231	Average Score: 2.44
# Episode 232	Average Score: 1.43
# Episode 233	Average Score: 7.52
# Episode 234	Average Score: 5.51
# Episode 235	Average Score: 6.01
# Episode 236	Average Score: 3.77
# Episode 237	Average Score: 2.97
# Episode 238	Average Score: 3.73
# Episode 239	Average Score: 1.04
# Episode 240	Average Score: 3.11
# Episode 240	Average Score of deque: 4.69
# Episode 241	Average Score: 5.65
# Episode 242	Average Score: 1.85
# Episode 243	Average Score: 2.77
# Episode 244	Average Score: 3.29
# Episode 245	Average Score: 5.59
# Episode 246	Average Score: 5.85
# Episode 247	Average Score: 3.80
# Episode 248	Average Score: 7.12
# Episode 249	Average Score: 4.45
# Episode 250	Average Score: 7.27
# Episode 251	Average Score: 6.41
# Episode 252	Average Score: 0.69
# Episode 253	Average Score: 1.25
# Episode 254	Average Score: 2.87
# Episode 255	Average Score: 3.81
# Episode 256	Average Score: 3.57
# Episode 257	Average Score: 2.47
# Episode 258	Average Score: 4.75
# Episode 259	Average Score: 6.59
# Episode 260	Average Score: 7.63
# Episode 260	Average Score of deque: 4.38
# Episode 261	Average Score: 5.79
# Episode 262	Average Score: 13.33
# Episode 263	Average Score: 13.25
# Episode 264	Average Score: 7.91
# Episode 265	Average Score: 8.52
# Episode 266	Average Score: 17.13
# Episode 267	Average Score: 4.06
# Episode 268	Average Score: 11.70
# Episode 269	Average Score: 12.31
# Episode 270	Average Score: 6.63
# Episode 271	Average Score: 3.03
# Episode 272	Average Score: 1.04
# Episode 273	Average Score: 6.22
# Episode 274	Average Score: 0.86
# Episode 275	Average Score: 4.11
# Episode 276	Average Score: 0.18
# Episode 277	Average Score: 6.39
# Episode 278	Average Score: 9.14
# Episode 279	Average Score: 10.00
# Episode 280	Average Score: 15.46
# Episode 280	Average Score of deque: 7.85
# Episode 281	Average Score: 4.81
# Episode 282	Average Score: 13.78
# Episode 283	Average Score: 21.63
# Episode 284	Average Score: 1.36
# Episode 285	Average Score: 3.94
# Episode 286	Average Score: 9.26
# Episode 287	Average Score: 15.81
# Episode 288	Average Score: 14.05
# Episode 289	Average Score: 3.05
# Episode 290	Average Score: 6.97
# Episode 291	Average Score: 16.40
# Episode 292	Average Score: 15.43
# Episode 293	Average Score: 12.38
# Episode 294	Average Score: 11.16
# Episode 295	Average Score: 5.60
# Episode 296	Average Score: 18.87
# Episode 297	Average Score: 16.54
# Episode 298	Average Score: 12.75
# Episode 299	Average Score: 13.29
# Episode 300	Average Score: 21.54
# Episode 300	Average Score of deque: 11.93
# Episode 301	Average Score: 19.41
# Episode 302	Average Score: 13.16
# Episode 303	Average Score: 5.86
# Episode 304	Average Score: 19.10
# Episode 305	Average Score: 27.32
# Episode 306	Average Score: 18.55
# Episode 307	Average Score: 18.26
# Episode 308	Average Score: 16.73
# Episode 309	Average Score: 29.91
# Episode 310	Average Score: 10.29
# Episode 311	Average Score: 13.90
# Episode 312	Average Score: 11.15
# Episode 313	Average Score: 3.35
# Episode 314	Average Score: 5.71
# Episode 315	Average Score: 21.31
# Episode 316	Average Score: 23.49
# Episode 317	Average Score: 12.04
# Episode 318	Average Score: 9.42
# Episode 319	Average Score: 8.26
# Episode 320	Average Score: 23.09
# Episode 320	Average Score of deque: 15.52
# Episode 321	Average Score: 6.76
# Episode 322	Average Score: 14.31
# Episode 323	Average Score: 7.59
# Episode 324	Average Score: 16.40
# Episode 325	Average Score: 9.79
# Episode 326	Average Score: 17.20
# Episode 327	Average Score: 0.00
# Episode 328	Average Score: 17.16
# Episode 329	Average Score: 14.09
# Episode 330	Average Score: 13.51
# Episode 331	Average Score: 6.87
# Episode 332	Average Score: 14.78
# Episode 333	Average Score: 15.48
# Episode 334	Average Score: 24.49
# Episode 335	Average Score: 9.87
# Episode 336	Average Score: 25.40
# Episode 337	Average Score: 23.05
# Episode 338	Average Score: 4.61
# Episode 339	Average Score: 18.70
# Episode 340	Average Score: 8.45
# Episode 340	Average Score of deque: 13.43
# Episode 341	Average Score: 5.99
# Episode 342	Average Score: 22.08
# Episode 343	Average Score: 10.78
# Episode 344	Average Score: 14.83
# Episode 345	Average Score: 5.47
# Episode 346	Average Score: 6.61
# Episode 347	Average Score: 30.13
# Episode 348	Average Score: 31.01
# Episode 349	Average Score: 18.30
# Episode 350	Average Score: 23.86
# Episode 351	Average Score: 10.39
# Episode 352	Average Score: 15.92
# Episode 353	Average Score: 18.48
# Episode 354	Average Score: 15.19
# Episode 355	Average Score: 0.77
# Episode 356	Average Score: 33.51
# Episode 357	Average Score: 10.62
# Episode 358	Average Score: 17.81
# Episode 359	Average Score: 28.55
# Episode 360	Average Score: 22.37
# Episode 360	Average Score of deque: 17.13
# Episode 361	Average Score: 12.24
# Episode 362	Average Score: 9.14
# Episode 363	Average Score: 29.56
# Episode 364	Average Score: 12.53
# Episode 365	Average Score: 10.11
# Episode 366	Average Score: 11.59
# Episode 367	Average Score: 34.22
# Episode 368	Average Score: 14.40
# Episode 369	Average Score: 23.67
# Episode 370	Average Score: 23.53
# Episode 371	Average Score: 4.88
# Episode 372	Average Score: 1.29
# Episode 373	Average Score: 9.86
# Episode 374	Average Score: 24.55
# Episode 375	Average Score: 17.50
# Episode 376	Average Score: 26.40
# Episode 377	Average Score: 23.22
# Episode 378	Average Score: 14.38
# Episode 379	Average Score: 19.49
# Episode 380	Average Score: 13.70
# Episode 380	Average Score of deque: 16.81
# Episode 381	Average Score: 19.26
# Episode 382	Average Score: 21.57
# Episode 383	Average Score: 2.74
# Episode 384	Average Score: 32.45
# Episode 385	Average Score: 17.48
# Episode 386	Average Score: 18.43
# Episode 387	Average Score: 17.41
# Episode 388	Average Score: 32.81
# Episode 389	Average Score: 26.08
# Episode 390	Average Score: 21.17
# Episode 391	Average Score: 18.85
# Episode 392	Average Score: 25.18
# Episode 393	Average Score: 23.18
# Episode 394	Average Score: 24.78
# Episode 395	Average Score: 30.92
# Episode 396	Average Score: 13.53
# Episode 397	Average Score: 32.50
# Episode 398	Average Score: 7.66
# Episode 399	Average Score: 29.37
# Episode 400	Average Score: 26.67
# Episode 400	Average Score of deque: 22.10
# Episode 401	Average Score: 20.90
# Episode 402	Average Score: 32.22
# Episode 403	Average Score: 28.97
# Episode 404	Average Score: 36.08
# Episode 405	Average Score: 19.22
# Episode 406	Average Score: 35.46
# Episode 407	Average Score: 24.94
# Episode 408	Average Score: 24.68
# Episode 409	Average Score: 7.85
# Episode 410	Average Score: 20.54
# Episode 411	Average Score: 15.12
# Episode 412	Average Score: 12.29
# Episode 413	Average Score: 26.71
# Episode 414	Average Score: 34.61
# Episode 415	Average Score: 7.74
# Episode 416	Average Score: 15.88
# Episode 417	Average Score: 24.97
# Episode 418	Average Score: 30.20
# Episode 419	Average Score: 2.05
# Episode 420	Average Score: 26.69
# Episode 420	Average Score of deque: 22.36
# Episode 421	Average Score: 14.24
# Episode 422	Average Score: 2.55
# Episode 423	Average Score: 3.77
# Episode 424	Average Score: 31.28
# Episode 425	Average Score: 21.01
# Episode 426	Average Score: 30.48
# Episode 427	Average Score: 19.57
# Episode 428	Average Score: 19.97
# Episode 429	Average Score: 18.53
# Episode 430	Average Score: 27.50
# Episode 431	Average Score: 26.02
# Episode 432	Average Score: 15.98
# Episode 433	Average Score: 20.88
# Episode 434	Average Score: 19.19
# Episode 435	Average Score: 15.68
# Episode 436	Average Score: 28.41
# Episode 437	Average Score: 28.22
# Episode 438	Average Score: 6.54
# Episode 439	Average Score: 32.09
# Episode 440	Average Score: 25.82
# Episode 440	Average Score of deque: 20.39
# Episode 441	Average Score: 23.76
# Episode 442	Average Score: 37.29
# Episode 443	Average Score: 22.90
# Episode 444	Average Score: 27.25
# Episode 445	Average Score: 17.80
# Episode 446	Average Score: 25.45
# Episode 447	Average Score: 11.25
# Episode 448	Average Score: 31.16
# Episode 449	Average Score: 17.32
# Episode 450	Average Score: 34.71
# Episode 451	Average Score: 7.25
# Episode 452	Average Score: 14.94
# Episode 453	Average Score: 16.44
# Episode 454	Average Score: 17.49
# Episode 455	Average Score: 25.44
# Episode 456	Average Score: 22.23
# Episode 457	Average Score: 16.05
# Episode 458	Average Score: 29.29
# Episode 459	Average Score: 13.21
# Episode 460	Average Score: 32.47
# Episode 460	Average Score of deque: 22.18
# Episode 461	Average Score: 25.36
# Episode 462	Average Score: 27.09
# Episode 463	Average Score: 0.00
# Episode 464	Average Score: 11.88
# Episode 465	Average Score: 35.34
# Episode 466	Average Score: 36.92
# Episode 467	Average Score: 5.52
# Episode 468	Average Score: 36.37
# Episode 469	Average Score: 24.17
# Episode 470	Average Score: 17.36
# Episode 471	Average Score: 21.87
# Episode 472	Average Score: 33.21
# Episode 473	Average Score: 32.77
# Episode 474	Average Score: 31.32
# Episode 475	Average Score: 8.53
# Episode 476	Average Score: 25.86
# Episode 477	Average Score: 29.50
# Episode 478	Average Score: 29.30
# Episode 479	Average Score: 34.57
# Episode 480	Average Score: 37.10
# Episode 480	Average Score of deque: 25.20
# Episode 481	Average Score: 30.77
# Episode 482	Average Score: 27.78
# Episode 483	Average Score: 14.76
# Episode 484	Average Score: 35.90
# Episode 485	Average Score: 25.00
# Episode 486	Average Score: 34.86
# Episode 487	Average Score: 34.35
# Episode 488	Average Score: 8.30
# Episode 489	Average Score: 19.16
# Episode 490	Average Score: 18.82
# Episode 491	Average Score: 27.61
# Episode 492	Average Score: 34.81
# Episode 493	Average Score: 36.95
# Episode 494	Average Score: 33.90
# Episode 495	Average Score: 36.40
# Episode 496	Average Score: 27.78
# Episode 497	Average Score: 25.18
# Episode 498	Average Score: 26.93
# Episode 499	Average Score: 24.34
# Episode 500	Average Score: 26.23
# Episode 500	Average Score of deque: 27.49
# Episode 501	Average Score: 27.93
# Episode 502	Average Score: 26.68
# Episode 503	Average Score: 28.68
# Episode 504	Average Score: 29.89
# Episode 505	Average Score: 28.94
# Episode 506	Average Score: 37.02
# Episode 507	Average Score: 32.46
# Episode 508	Average Score: 28.19
# Episode 509	Average Score: 34.76
# Episode 510	Average Score: 26.08
#
# Environment solved in 510 episodes!	Average Score of deque: 30.04
# duration: 33.14849838813146

# %%
env.close()
